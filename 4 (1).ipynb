# %%
import pandas as pd
from scipy.stats import zscore, skew
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\malus\Downloads\StudentsPerformance.csv")

# %%
print(df.isnull().sum())
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df['math score'] = df['math score'].fillna(df['math score'].mean())
df['gender'] = df['gender'].fillna(df['gender'].mode()[0])

# %%
skew(df['math score'])
# Out:
# -0.278516571914075

# %%
df['math_zscore'] = zscore(df['math score'])

# %%
skew(df['math_zscore'])
# Out:
# -0.27851657191407503

# %%
sns.histplot(df['math score'] ,kde=True,color='blue')
plt.title('Original Math Score Distribution')
# Out:
# Text(0.5, 1.0, 'Original Math Score Distribution')

# %%
sns.histplot(df['math_zscore'], kde=True, color='green')
plt.title('Z-Score Transformed Math Score Distribution')
# Out:
# Text(0.5, 1.0, 'Z-Score Transformed Math Score Distribution')

# %%
df['math_score_log'] = np.log1p(df['math score'])

# %%
sns.histplot(df['math_score_log'], kde=True)
plt.title("Log-Transformed Distribution of Math Score")
# Out:
# Text(0.5, 1.0, 'Log-Transformed Distribution of Math Score')

# %%
skew(df['math_score_log'])
# Out:
# -4.095115931496016
