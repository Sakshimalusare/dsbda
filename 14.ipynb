# %%
import pandas as pd

# Read the data
df = pd.read_csv(r"C:\Users\malus\OneDrive\Desktop\dsbda\weather.csv")
df
# Out:
#       location        date  precipitation  temp_max  temp_min  wind  weather
# 0      Seattle  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1      Seattle  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2      Seattle  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3      Seattle  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4      Seattle  2012-01-05            1.3       8.9       2.8   6.1     rain
# ...        ...         ...            ...       ...       ...   ...      ...
# 2917  New York  2015-12-27            2.0      17.2       8.9   5.5     rain
# 2918  New York  2015-12-28            1.3       8.9       1.7   6.3     snow
# 2919  New York  2015-12-29           16.8       9.4       1.1   5.3     rain
# 2920  New York  2015-12-30            9.4      10.6       5.0   3.0     rain
# 2921  New York  2015-12-31            1.5      11.1       6.1   5.5     rain
#
# [2922 rows x 7 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['Year'] = df['date'].dt.year
df['Month'] = df['date'].dt.month

# %%
yearly_avg = df.groupby('Year')[['temp_max','temp_min', 'precipitation', 'wind']].mean()

# %%
monthly_avg = df.groupby(['Year', 'Month'])[['temp_max','temp_min', 'precipitation', 'wind']].mean()

# %%
print("Year-wise Averages:\n", yearly_avg)
print("\nMonth-wise Averages:\n", monthly_avg)
# Out:
# Year-wise Averages:
#         temp_max  temp_min  precipitation      wind
# Year
# 2012  16.578142  8.611066       3.058060  4.123087
# 2013  16.334795  8.355479       2.370822  4.044658
# 2014  16.644110  8.437945       3.455616  4.220137
# 2015  17.520000  9.044795       2.894247  4.016575
#
# Month-wise Averages:
#               temp_max   temp_min  precipitation      wind
# Year Month
# 2012 1       7.032258   0.135484       3.691935  4.929032
#      2       8.932759   1.946552       2.143103  4.653448
#      3      11.419355   3.937097       3.414516  4.682258
#      4      16.055000   6.651667       2.391667  4.511667
#      5      19.524194  11.159677       3.746774  3.630645
#      6      22.346667  13.808333       4.163333  3.791667
#      7      26.454839  17.235484       1.054839  3.475806
#      8      27.362903  17.427419       1.650000  3.377419
#      9      23.705000  14.000000       1.731667  3.610000
#      10     17.182258   9.979032       3.659677  4.198387
# ...
